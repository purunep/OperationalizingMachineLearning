# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.19.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-130816
# aml-quickstarts-130816
# southcentralus
# 2552278b-2817-43a7-820e-5a5a53ff9e19

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'experiment-pipeline'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: experiment-pipeline,
# Workspace: quick-starts-ws-130816)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "puru-compute"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketingDS"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 30,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [fb758171][9bf9fde3-1e37-47c4-9272-63d0b65856b4], (This step will run and generate new outputs)
# Submitted PipelineRun aa549f09-0d06-46e6-a7b9-5a8147a711cd
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/experiment-pipeline/runs/aa549f09-0d06-46e6-a7b9-5a8147a711cd?wsid=/subscriptions/2552278b-2817-43a7-820e-5a5a53ff9e19/resourcegroups/aml-quickstarts-130816/workspaces/quick-starts-ws-130816

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# WARNING:azureml.pipeline.core.run:Expected a StepRun object but received <class 'azureml.core.run.Run'> instead.
# This usually indicates a package conflict with one of the dependencies of azureml-core or azureml-pipeline-core.
# Please check for package conflicts in your python environment
# PipelineRunId: aa549f09-0d06-46e6-a7b9-5a8147a711cd
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/experiment-pipeline/runs/aa549f09-0d06-46e6-a7b9-5a8147a711cd?wsid=/subscriptions/2552278b-2817-43a7-820e-5a5a53ff9e19/resourcegroups/aml-quickstarts-130816/workspaces/quick-starts-ws-130816
# PipelineRun Status: Running
#
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'aa549f09-0d06-46e6-a7b9-5a8147a711cd', 'status': 'Completed', 'startTimeUtc': '2020-12-17T16:55:27.38922Z', 'endTimeUtc': '2020-12-17T17:27:53.899779Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg130816.blob.core.windows.net/azureml/ExperimentRun/dcid.aa549f09-0d06-46e6-a7b9-5a8147a711cd/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=U%2BfwvyLGr3wHHrrmwmA7rDW70OaSNi%2B0AXBZF0F1Y24%3D&st=2020-12-17T16%3A45%3A51Z&se=2020-12-18T00%3A55%3A51Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg130816.blob.core.windows.net/azureml/ExperimentRun/dcid.aa549f09-0d06-46e6-a7b9-5a8147a711cd/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=HQzRP3x53sCwgDrwWMUoUyu0vfxXYiY8iapBqNvdJIg%3D&st=2020-12-17T16%3A45%3A52Z&se=2020-12-18T00%3A55%3A52Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg130816.blob.core.windows.net/azureml/ExperimentRun/dcid.aa549f09-0d06-46e6-a7b9-5a8147a711cd/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=Bg0tKBP8V%2FnyxSWrqZEttuwB3LLjd1Csu5JAyjwHBrA%3D&st=2020-12-17T16%3A45%3A52Z&se=2020-12-18T00%3A55%3A52Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/65e0f9a2-f26d-4d7d-96aa-f030b9f36579/metrics_data
# Downloaded azureml/65e0f9a2-f26d-4d7d-96aa-f030b9f36579/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_11  \
# precision_score_micro                               [0.7341426403641882]
# accuracy                                            [0.7341426403641882]
# AUC_macro                                           [0.8770026507510461]
# precision_score_weighted                            [0.8878069719583428]
# f1_score_macro                                       [0.615372930032045]
# average_precision_score_macro                       [0.7335070800296515]
# recall_score_macro                                  [0.7614977021267137]
# recall_score_micro                                  [0.7341426403641882]
# average_precision_score_weighted                     [0.926979926224294]
# AUC_micro                                           [0.8514879536521284]
# balanced_accuracy                                   [0.7614977021267137]
# precision_score_macro                               [0.6172011207970112]
# recall_score_weighted                               [0.7341426403641882]
# f1_score_micro                                      [0.7341426403641882]
# norm_macro_recall                                   [0.5229954042534275]
# f1_score_weighted                                   [0.7812353818721818]
# log_loss                                              [0.49888255447243]
# average_precision_score_micro                       [0.8608226872592072]
# matthews_correlation                               [0.35013039728132045]
# weighted_accuracy                                   [0.7273511184704536]
# AUC_weighted                                         [0.877002650751046]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_29  \
# precision_score_micro                                [0.910773899848255]
# accuracy                                             [0.910773899848255]
# AUC_macro                                           [0.9384936843216689]
# precision_score_weighted                            [0.9046131382658897]
# f1_score_macro                                      [0.7570512396097291]
# average_precision_score_macro                       [0.8107145618805784]
# recall_score_macro                                  [0.7378011732953966]
# recall_score_micro                                   [0.910773899848255]
# average_precision_score_weighted                     [0.951452697462513]
# AUC_micro                                           [0.9780903147961804]
# balanced_accuracy                                   [0.7378011732953966]
# precision_score_macro                               [0.7815422994681727]
# recall_score_weighted                                [0.910773899848255]
# f1_score_micro                                      [0.9107738998482551]
# norm_macro_recall                                  [0.47560234659079326]
# f1_score_weighted                                   [0.9070202751800881]
# log_loss                                           [0.21277804859414967]
# average_precision_score_micro                       [0.9791136862713432]
# matthews_correlation                                [0.5174981706086134]
# weighted_accuracy                                   [0.9537183490182449]
# AUC_weighted                                        [0.9384936843216688]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_27  \
# precision_score_micro                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# AUC_macro                                           [0.9306266405111078]
# precision_score_weighted                             [0.788565560086672]
# f1_score_macro                                      [0.4703423886834914]
# average_precision_score_macro                       [0.7904832503311506]
# recall_score_macro                                                 [0.5]
# recall_score_micro                                  [0.8880121396054628]
# average_precision_score_weighted                    [0.9459201488993374]
# AUC_micro                                           [0.9736608325024582]
# balanced_accuracy                                                  [0.5]
# precision_score_macro                               [0.4440060698027314]
# recall_score_weighted                               [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# log_loss                                            [0.2684414628119108]
# average_precision_score_micro                         [0.97474986519737]
# matthews_correlation                                               [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_weighted                                        [0.9306266405111078]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_12  \
# precision_score_micro                                [0.730804248861912]
# accuracy                                             [0.730804248861912]
# AUC_macro                                           [0.8523692824077934]
# precision_score_weighted                            [0.8827083233915254]
# f1_score_macro                                      [0.6084350060911882]
# average_precision_score_macro                       [0.7095235032747855]
# recall_score_macro                                  [0.7465925530752231]
# recall_score_micro                                   [0.730804248861912]
# average_precision_score_weighted                    [0.9184861568520946]
# AUC_micro                                           [0.8287261013030734]
# balanced_accuracy                                   [0.7465925530752231]
# precision_score_macro                               [0.6110868418724893]
# recall_score_weighted                                [0.730804248861912]
# f1_score_micro                                      [0.7308042488619121]
# norm_macro_recall                                   [0.4931851061504462]
# f1_score_weighted                                    [0.778303710632307]
# log_loss                                            [0.5964004449778979]
# average_precision_score_micro                       [0.8307075509220829]
# matthews_correlation                               [0.33101775149016244]
# weighted_accuracy                                   [0.7268844399921497]
# AUC_weighted                                        [0.8523692824077933]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_23  \
# precision_score_micro                               [0.9101669195751139]
# accuracy                                            [0.9101669195751139]
# AUC_macro                                           [0.9342679499932389]
# precision_score_weighted                            [0.9000274768383943]
# f1_score_macro                                      [0.7372589501995638]
# average_precision_score_macro                       [0.7998321444303222]
# recall_score_macro                                   [0.705487851187466]
# recall_score_micro                                  [0.9101669195751139]
# average_precision_score_weighted                    [0.9486146431518476]
# AUC_micro                                           [0.9766515228619257]
# balanced_accuracy                                    [0.705487851187466]
# precision_score_macro                               [0.7882750842617063]
# recall_score_weighted                               [0.9101669195751139]
# f1_score_micro                                      [0.9101669195751139]
# norm_macro_recall                                   [0.4109757023749321]
# f1_score_weighted                                   [0.9026632441364442]
# log_loss                                            [0.1921852994995217]
# average_precision_score_micro                       [0.9777871805237555]
# matthews_correlation                                [0.4867731611986173]
# weighted_accuracy                                   [0.9609831957806473]
# AUC_weighted                                        [0.9342679499932388]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_24  \
# precision_score_micro                               [0.9138088012139606]
# accuracy                                            [0.9138088012139606]
# AUC_macro                                           [0.9440702643526777]
# precision_score_weighted                            [0.9085876546672915]
# f1_score_macro                                      [0.7677536498053239]
# average_precision_score_macro                       [0.8167288234994515]
# recall_score_macro                                  [0.7501671769964453]
# recall_score_micro                                  [0.9138088012139606]
# average_precision_score_weighted                    [0.9534157741149873]
# AUC_micro                                           [0.9794490663878916]
# balanced_accuracy                                   [0.7501671769964453]
# precision_score_macro                               [0.7893870143116419]
# recall_score_weighted                               [0.9138088012139606]
# f1_score_micro                                      [0.9138088012139606]
# norm_macro_recall                                   [0.5003343539928906]
# f1_score_weighted                                   [0.9106786487153445]
# log_loss                                           [0.18047415972399278]
# average_precision_score_micro                       [0.9804154714516231]
# matthews_correlation                                [0.5381268713966005]
# weighted_accuracy                                   [0.9544365900761322]
# AUC_weighted                                        [0.9440702643526778]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_38  \
# precision_score_micro                               [0.9119878603945372]
# accuracy                                            [0.9119878603945372]
# AUC_macro                                           [0.9461171405972433]
# precision_score_weighted                            [0.9005745138864382]
# f1_score_macro                                      [0.7275698046245991]
# average_precision_score_macro                       [0.8218148623548338]
# recall_score_macro                                  [0.6875670328815386]
# recall_score_micro                                  [0.9119878603945372]
# average_precision_score_weighted                    [0.9547584429203732]
# AUC_micro                                           [0.9797907806236054]
# balanced_accuracy                                   [0.6875670328815386]
# precision_score_macro                                [0.805821504077318]
# recall_score_weighted                               [0.9119878603945372]
# f1_score_micro                                      [0.9119878603945372]
# norm_macro_recall                                   [0.3751340657630773]
# f1_score_weighted                                   [0.9015118808340169]
# log_loss                                            [0.2048263711342109]
# average_precision_score_micro                        [0.980737292952786]
# matthews_correlation                               [0.47900744090734926]
# weighted_accuracy                                   [0.9677054813853464]
# AUC_weighted                                        [0.9461171405972433]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_15  \
# precision_score_micro                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# AUC_macro                                           [0.8707694031827536]
# precision_score_weighted                             [0.788565560086672]
# f1_score_macro                                      [0.4703423886834914]
# average_precision_score_macro                       [0.6864838375932966]
# recall_score_macro                                                 [0.5]
# recall_score_micro                                  [0.8880121396054628]
# average_precision_score_weighted                    [0.9150049185747059]
# AUC_micro                                           [0.9617556374789594]
# balanced_accuracy                                                  [0.5]
# precision_score_macro                               [0.4440060698027314]
# recall_score_weighted                               [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# log_loss                                            [0.2643189799178264]
# average_precision_score_micro                        [0.961476826173018]
# matthews_correlation                                               [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_weighted                                        [0.8707694031827536]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_20  \
# precision_score_micro                               [0.9125948406676783]
# accuracy                                            [0.9125948406676783]
# AUC_macro                                           [0.9424512871239443]
# precision_score_weighted                            [0.9064419404986112]
# f1_score_macro                                      [0.7613817409356443]
# average_precision_score_macro                       [0.8131628841963428]
# recall_score_macro                                  [0.7411947273949842]
# recall_score_micro                                  [0.9125948406676783]
# average_precision_score_weighted                    [0.9524536910133203]
# AUC_micro                                           [0.9790159827392864]
# balanced_accuracy                                   [0.7411947273949842]
# precision_score_macro                               [0.7872528061629692]
# recall_score_weighted                               [0.9125948406676783]
# f1_score_micro                                      [0.9125948406676783]
# norm_macro_recall                                   [0.4823894547899683]
# f1_score_weighted                                   [0.9087900123862012]
# log_loss                                           [0.18386077817913915]
# average_precision_score_micro                       [0.9800107530929907]
# matthews_correlation                                [0.5264365575296669]
# weighted_accuracy                                    [0.955148852498673]
# AUC_weighted                                        [0.9424512871239444]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_2  ...  \
# precision_score_micro                               [0.898937784522003]  ...
# accuracy                                            [0.898937784522003]  ...
# AUC_macro                                          [0.8993145280051571]  ...
# precision_score_weighted                           [0.8837257704896572]  ...
# f1_score_macro                                     [0.6004127576867652]  ...
# average_precision_score_macro                      [0.7494334447680999]  ...
# recall_score_macro                                 [0.5736472556113121]  ...
# recall_score_micro                                  [0.898937784522003]  ...
# average_precision_score_weighted                   [0.9320094274554432]  ...
# AUC_micro                                          [0.9677079126187883]  ...
# balanced_accuracy                                  [0.5736472556113121]  ...
# precision_score_macro                              [0.8168922311757251]  ...
# recall_score_weighted                               [0.898937784522003]  ...
# f1_score_micro                                     [0.8989377845220029]  ...
# norm_macro_recall                                 [0.14729451122262427]  ...
# f1_score_weighted                                  [0.8684354029177002]  ...
# log_loss                                          [0.24081289844726414]  ...
# average_precision_score_micro                        [0.96784824602269]  ...
# matthews_correlation                              [0.30553718693892323]  ...
# weighted_accuracy                                  [0.9796986238906038]  ...
# AUC_weighted                                       [0.8993145280051571]  ...
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_1  \
# precision_score_micro                              [0.9071320182094081]
# accuracy                                           [0.9071320182094081]
# AUC_macro                                          [0.9392346349984347]
# precision_score_weighted                           [0.8991976076061607]
# f1_score_macro                                     [0.7416848907681176]
# average_precision_score_macro                      [0.8065229883244922]
# recall_score_macro                                 [0.7191727470931578]
# recall_score_micro                                 [0.9071320182094081]
# average_precision_score_weighted                   [0.9505970434373063]
# AUC_micro                                          [0.9781770788959222]
# balanced_accuracy                                  [0.7191727470931578]
# precision_score_macro                              [0.7723958081530135]
# recall_score_weighted                              [0.9071320182094081]
# f1_score_micro                                     [0.9071320182094081]
# norm_macro_recall                                 [0.43834549418631563]
# f1_score_weighted                                  [0.9021127651963996]
# log_loss                                           [0.1874363495858499]
# average_precision_score_micro                      [0.9791945367231853]
# matthews_correlation                                [0.488678780261868]
# weighted_accuracy                                  [0.9537972210153172]
# AUC_weighted                                       [0.9392346349984347]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_5  \
# precision_score_micro                               [0.898937784522003]
# accuracy                                            [0.898937784522003]
# AUC_macro                                          [0.9083795964412139]
# precision_score_weighted                           [0.8811157550701237]
# f1_score_macro                                     [0.6132139688332033]
# average_precision_score_macro                      [0.7365636028415987]
# recall_score_macro                                 [0.5831203100137632]
# recall_score_micro                                  [0.898937784522003]
# average_precision_score_weighted                   [0.9311370609947727]
# AUC_micro                                          [0.9695737091882906]
# balanced_accuracy                                  [0.5831203100137632]
# precision_score_macro                              [0.7982595199638411]
# recall_score_weighted                               [0.898937784522003]
# f1_score_micro                                     [0.8989377845220029]
# norm_macro_recall                                 [0.16624062002752638]
# f1_score_weighted                                   [0.871192710611544]
# log_loss                                          [0.23054188241948298]
# average_precision_score_micro                       [0.970108730265699]
# matthews_correlation                               [0.3149058510980744]
# weighted_accuracy                                  [0.9773467207242611]
# AUC_weighted                                       [0.9083795964412138]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_9  \
# precision_score_micro                              [0.7341426403641882]
# accuracy                                           [0.7341426403641882]
# AUC_macro                                          [0.8330675172780436]
# precision_score_weighted                           [0.8798499570719374]
# f1_score_macro                                     [0.6080291542592313]
# average_precision_score_macro                       [0.709600869338888]
# recall_score_macro                                 [0.7389991979208923]
# recall_score_micro                                 [0.7341426403641882]
# average_precision_score_weighted                   [0.9137158927264998]
# AUC_micro                                          [0.8248813095668471]
# balanced_accuracy                                  [0.7389991979208923]
# precision_score_macro                              [0.6090842529863889]
# recall_score_weighted                              [0.7341426403641882]
# f1_score_micro                                     [0.7341426403641882]
# norm_macro_recall                                  [0.4779983958417846]
# f1_score_weighted                                  [0.7805664383525297]
# log_loss                                           [0.5519319022420981]
# average_precision_score_micro                      [0.7924211989284322]
# matthews_correlation                               [0.3229306363264201]
# weighted_accuracy                                  [0.7329368884905176]
# AUC_weighted                                       [0.8330675172780437]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_17  \
# precision_score_micro                               [0.7547799696509864]
# accuracy                                            [0.7547799696509864]
# AUC_macro                                           [0.8196641826295229]
# precision_score_weighted                            [0.8805366434027561]
# f1_score_macro                                      [0.6228109844350523]
# average_precision_score_macro                       [0.7056846866675057]
# recall_score_macro                                  [0.7435143661074342]
# recall_score_micro                                  [0.7547799696509864]
# average_precision_score_weighted                    [0.9084722877686885]
# AUC_micro                                            [0.832582774747226]
# balanced_accuracy                                   [0.7435143661074342]
# precision_score_macro                               [0.6160960062454575]
# recall_score_weighted                               [0.7547799696509864]
# f1_score_micro                                      [0.7547799696509864]
# norm_macro_recall                                   [0.4870287322148683]
# f1_score_weighted                                   [0.7959483344592407]
# log_loss                                            [0.5667460919305917]
# average_precision_score_micro                       [0.8003749623124202]
# matthews_correlation                                [0.3362799153590192]
# weighted_accuracy                                   [0.7575769142814307]
# AUC_weighted                                        [0.8196641826295228]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_26  \
# precision_score_micro                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# AUC_macro                                           [0.9010798429925516]
# precision_score_weighted                             [0.788565560086672]
# f1_score_macro                                      [0.4703423886834914]
# average_precision_score_macro                       [0.7277523358032929]
# recall_score_macro                                                 [0.5]
# recall_score_micro                                  [0.8880121396054628]
# average_precision_score_weighted                     [0.928476377825117]
# AUC_micro                                           [0.9677841766045487]
# balanced_accuracy                                                  [0.5]
# precision_score_macro                               [0.4440060698027314]
# recall_score_weighted                               [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# log_loss                                            [0.2741738187506259]
# average_precision_score_micro                       [0.9688318926888022]
# matthews_correlation                                               [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_weighted                                        [0.9010798429925517]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_39  \
# precision_score_micro                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# AUC_macro                                           [0.9453919351223588]
# precision_score_weighted                             [0.788565560086672]
# f1_score_macro                                      [0.4703423886834914]
# average_precision_score_macro                       [0.8203988559292601]
# recall_score_macro                                                 [0.5]
# recall_score_micro                                  [0.8880121396054628]
# average_precision_score_weighted                    [0.9543728061547666]
# AUC_micro                                           [0.9765975485918106]
# balanced_accuracy                                                  [0.5]
# precision_score_macro                               [0.4440060698027314]
# recall_score_weighted                               [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# log_loss                                           [0.31696476748488905]
# average_precision_score_micro                       [0.9778262687420773]
# matthews_correlation                                               [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_weighted                                        [0.9453919351223588]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_0  \
# precision_score_micro                              [0.9116843702579667]
# accuracy                                           [0.9116843702579667]
# AUC_macro                                          [0.9450464668693166]
# precision_score_weighted                           [0.9072720074188747]
# f1_score_macro                                     [0.7653697272147331]
# average_precision_score_macro                      [0.8151093723721079]
# recall_score_macro                                 [0.7513392683482543]
# recall_score_micro                                 [0.9116843702579667]
# average_precision_score_weighted                   [0.9531771295804466]
# AUC_micro                                           [0.979695082216353]
# balanced_accuracy                                  [0.7513392683482543]
# precision_score_macro                              [0.7819118765348991]
# recall_score_weighted                              [0.9116843702579667]
# f1_score_micro                                     [0.9116843702579667]
# norm_macro_recall                                  [0.5026785366965085]
# f1_score_weighted                                  [0.9091539479147899]
# log_loss                                          [0.17775706110025447]
# average_precision_score_micro                      [0.9806603102489483]
# matthews_correlation                               [0.5323740218566827]
# weighted_accuracy                                  [0.9514937218005303]
# AUC_weighted                                       [0.9450464668693167]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_7  \
# precision_score_micro                              [0.8883156297420334]
# accuracy                                           [0.8883156297420334]
# AUC_macro                                          [0.8524137394483993]
# precision_score_weighted                           [0.9007928150046113]
# f1_score_macro                                    [0.47312070913357085]
# average_precision_score_macro                      [0.7208017265618172]
# recall_score_macro                                 [0.5013550135501355]
# recall_score_micro                                 [0.8883156297420334]
# average_precision_score_weighted                   [0.9198483313364457]
# AUC_micro                                          [0.9581050978513911]
# balanced_accuracy                                  [0.5013550135501355]
# precision_score_macro                              [0.9441408621736491]
# recall_score_weighted                              [0.8883156297420334]
# f1_score_micro                                     [0.8883156297420334]
# norm_macro_recall                               [0.0027100271002709064]
# f1_score_weighted                                  [0.8360791405851395]
# log_loss                                          [0.27261921834625175]
# average_precision_score_micro                       [0.958341305503646]
# matthews_correlation                             [0.049063912865329386]
# weighted_accuracy                                  [0.9843874836349229]
# AUC_weighted                                       [0.8524137394483993]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_25  \
# precision_score_micro                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# AUC_macro                                           [0.9100860984686403]
# precision_score_weighted                             [0.788565560086672]
# f1_score_macro                                      [0.4703423886834914]
# average_precision_score_macro                       [0.7440177087576056]
# recall_score_macro                                                 [0.5]
# recall_score_micro                                  [0.8880121396054628]
# average_precision_score_weighted                    [0.9333441512635487]
# AUC_micro                                           [0.9695754592072875]
# balanced_accuracy                                                  [0.5]
# precision_score_macro                               [0.4440060698027314]
# recall_score_weighted                               [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# log_loss                                            [0.2880940127519761]
# average_precision_score_micro                       [0.9709129059400662]
# matthews_correlation                                               [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_weighted                                        [0.9100860984686403]
#
#                                  65e0f9a2-f26d-4d7d-96aa-f030b9f36579_35
# precision_score_micro                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# AUC_macro                                           [0.9249930998968227]
# precision_score_weighted                             [0.788565560086672]
# f1_score_macro                                      [0.4703423886834914]
# average_precision_score_macro                       [0.7825761605827746]
# recall_score_macro                                                 [0.5]
# recall_score_micro                                  [0.8880121396054628]
# average_precision_score_weighted                     [0.943523946918008]
# AUC_micro                                           [0.9725403598131164]
# balanced_accuracy                                                  [0.5]
# precision_score_macro                               [0.4440060698027314]
# recall_score_weighted                               [0.8880121396054628]
# f1_score_micro                                      [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# log_loss                                           [0.31136044745279967]
# average_precision_score_micro                       [0.9736443067968061]
# matthews_correlation                                               [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_weighted                                        [0.9249930998968227]
#
# [21 rows x 39 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/65e0f9a2-f26d-4d7d-96aa-f030b9f36579/model_data
# Downloaded azureml/65e0f9a2-f26d-4d7d-96aa-f030b9f36579/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                      min_weight_fraction_leaf=0.0,
#                                                                                                                                      n_estimators=10,
#                                                                                                                                      n_jobs=1,
#                                                                                                                                      oob_score=False,
#                                                                                                                                      random_state=None,
#                                                                                                                                      verbose=0,
#                                                                                                                                      warm_start=False))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.3333333333333333,
#                                                                                          0.13333333333333333,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667,
#                                                                                          0.3333333333333333,
#                                                                                          0.06666666666666667]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('0',
#                                              Pipeline(memory=None,
#                                                       steps=[('maxabsscaler',
#                                                               MaxAbsScaler(copy=True)),
#                                                              ('lightgbmclassifier',
#                                                               LightGBMClassifier(boosting_type='gbdt',
#                                                                                  class_weight=None,
#                                                                                  colsample_bytree=1.0,
#                                                                                  importance_type='split',
#                                                                                  learning_rate=0.1,
#                                                                                  max_depth=-1,
#                                                                                  min_child_samples=20,
#                                                                                  min_child_weight=0.001,
#                                                                                  min_spl...
#                                                                                      min_impurity_split=None,
#                                                                                      min_samples_leaf=0.01,
#                                                                                      min_samples_split=0.2442105263157895,
#                                                                                      min_weight_fraction_leaf=0.0,
#                                                                                      n_estimators=10,
#                                                                                      n_jobs=1,
#                                                                                      oob_score=False,
#                                                                                      random_state=None,
#                                                                                      verbose=0,
#                                                                                      warm_start=False))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.3333333333333333, 0.13333333333333333,
#                                          0.06666666666666667, 0.06666666666666667,
#                                          0.3333333333333333,
#                                          0.06666666666666667]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_ccd9380c_408d_11eb_862b_000d3aed907arow0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_ccd9380c_408d_11eb_862b_000d3aed907arow0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_ccd9380c_408d_11eb_862b_000d3aed907arow1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_ccd9380c_408d_11eb_862b_000d3aed907arow1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_ccd9380c_408d_11eb_862b_000d3aed907a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ccd9380c_408d_11eb_862b_000d3aed907alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ccd9380c_408d_11eb_862b_000d3aed907arow0_col0" class="data row0 col0" >28802</td>
#                         <td id="T_ccd9380c_408d_11eb_862b_000d3aed907arow0_col1" class="data row0 col1" >456</td>
#             </tr>
#             <tr>
#                         <th id="T_ccd9380c_408d_11eb_862b_000d3aed907alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ccd9380c_408d_11eb_862b_000d3aed907arow1_col0" class="data row1 col0" >1907</td>
#                         <td id="T_ccd9380c_408d_11eb_862b_000d3aed907arow1_col1" class="data row1 col1" >1785</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 5c373eb2-bb24-4e27-9592-bb32ca9e593b,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/2552278b-2817-43a7-820e-5a5a53ff9e19/resourceGroups/aml-quickstarts-130816/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-130816/PipelineRuns/PipelineSubmit/5c373eb2-bb24-4e27-9592-bb32ca9e593b)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "experiment-pipeline"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  7503c805-b1bf-4de7-a451-af69e4d60f30

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["experiment-pipeline"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
